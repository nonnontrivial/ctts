# %%
import pandas as pd

# %%
data=pd.read_csv("../sites.csv")
data.head()
# Out:
#    mpsas  elevation  cloud_cover  air_moisture  moon_phase  temperature
# 0   16.0          1          8.7           2.7        39.5         53.0
# 1   17.0          2          9.0           2.9        69.8         64.9
# 2   19.2          3         13.9           5.7        25.4         96.7
# 3   19.0          4         14.2           5.2         5.7        169.6
# 4   19.2          5         16.2           6.5        21.3        195.0
